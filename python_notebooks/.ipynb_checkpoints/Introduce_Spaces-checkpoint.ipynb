# %%
import csv
import pdb
file = '../../data/outputs/random_lm_30_epoch_June_27_Conll_glove/predictions/chunk_pred_test0.txt'

res = []

with open(file, 'rt') as csvfile:
    reader = csv.reader(csvfile, delimiter=' ')
    for row in reader:
        res.append(row)
        if row[0]=='.':
            res.append([])

# %%
res_file = '../../data/outputs/random_lm_30_epoch_June_27_Conll_glove/predictions/chunk_pred_test.txt'

with open(res_file,'wt') as resfil:
    writer = csv.writer(resfil, delimiter=' ')
    for r in res:
        writer.writerow(r)

# %%
import pandas as pd
a = pd.DataFrame(res)

# %%
a
# Out:
#                    0     1       2       3
# 0           Rockwell   NNP    B-NP    B-NP
# 1      International   NNP    I-NP    I-NP
# 2              Corp.   NNP    I-NP    I-NP
# 3                 's   POS    B-NP    B-NP
# 4              Tulsa   NNP    I-NP    I-NP
# 5               unit    NN    I-NP    I-NP
# 6               said   VBD    B-VP    B-VP
# 7                 it   PRP    B-NP    B-NP
# 8             signed   VBD    B-VP    B-VP
# 9                  a    DT    B-NP    B-NP
# 10         tentative    JJ    I-NP    I-NP
# 11         agreement    NN    I-NP    I-NP
# 12         extending   VBG    B-VP    B-VP
# 13               its  PRP$    B-NP    B-NP
# 14          contract    NN    I-NP    I-NP
# 15              with    IN    B-PP    B-PP
# 16            Boeing   NNP    B-NP    B-NP
# 17               Co.   NNP    I-NP    I-NP
# 18                to    TO    B-VP    B-VP
# 19           provide    VB    I-VP    I-VP
# 20        structural    JJ    B-NP    B-NP
# 21             parts   NNS    I-NP    I-NP
# 22               for    IN    B-PP    B-PP
# 23            Boeing   NNP    B-NP    B-NP
# 24                's   POS    B-NP    B-NP
# 25               747    CD    I-NP    I-NP
# 26         jetliners   NNS    I-NP    I-NP
# 27                 .     .       O       O
# 28              None  None    None    None
# 29          Rockwell   NNP    B-NP    B-NP
# ...              ...   ...     ...     ...
# 49299           None  None    None    None
# 49300             In    IN    B-PP    B-PP
# 49301            Los   NNP    B-NP    B-NP
# 49302        Angeles   NNP    I-NP    I-NP
# 49303              ,     ,       O       O
# 49304            for    IN    B-PP    B-PP
# 49305        example    NN    B-NP    B-NP
# 49306              ,     ,       O       O
# 49307        Central   NNP    B-NP    B-NP
# 49308            has   VBZ    B-VP    B-VP
# 49309            had   VBN    I-VP    I-VP
# 49310              a    DT    B-NP    B-NP
# 49311         strong    JJ    I-NP    I-NP
# 49312         market    NN    I-NP    I-NP
# 49313       position    NN    I-NP    I-NP
# 49314          while    IN  B-SBAR  B-SBAR
# 49315         Unilab   NNP    B-NP    B-NP
# 49316             's   POS    B-NP    B-NP
# 49317       presence    NN    I-NP    I-NP
# 49318            has   VBZ    B-VP    B-VP
# 49319           been   VBN    I-VP    I-VP
# 49320           less   RBR  B-ADJP  B-ADJP
# 49321      prominent    JJ  I-ADJP  I-ADJP
# 49322              ,     ,       O       O
# 49323      according   VBG    B-PP    B-PP
# 49324             to    TO    B-PP    B-PP
# 49325            Mr.   NNP    B-NP    B-NP
# 49326         Harlow   NNP    I-NP    I-NP
# 49327              .     .       O       O
# 49328           None  None    None    None
#
# [49329 rows x 4 columns]

# %%
# Out:
# [2, [2]]

# %%
# Out:
# [2, [2], []]
