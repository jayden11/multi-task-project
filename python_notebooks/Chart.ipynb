# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
valid_no_ptb = [
0.867161,
0.887069,
0.893184,
0.896821,
0.899704,
0.900647,
0.902452,
0.902290,
0.903556,
0.902505,
0.902425,
0.903718,
0.902613,
0.903637,
0.903987,
0.904014,
0.903879,
0.904283,
0.905630,
0.905577,
0.905119,
0.905253,
0.906008,
0.905577,
0.905603,
0.905442,
0.906519,
0.905792,
0.906250,
0.906950
]
train_no_ptb = [
0.701533,
0.882767,
0.897262,
0.905066,
0.910012,
0.913137,
0.915393,
0.917579,
0.918622,
0.920073,
0.921046,
0.922240,
0.922915,
0.924536,
0.924475,
0.926213,
0.926339,
0.927530,
0.927658,
0.928504,
0.929245,
0.929186,
0.929853,
0.930938,
0.931357,
0.931735,
0.931951,
0.932575,
0.933250,
0.932991]

# %%
trainminus_no_ptb = [1-x for x in train_no_ptb]
validminus_no_ptb = [1-y for y in valid_no_ptb]

plt.plot(trainminus_no_ptb, label='train')
plt.plot(validminus_no_ptb, label='validation')
plt.ylabel('Chunk Validation Error (Accuracy)')
plt.xlabel('Epoch')
plt.legend()
plt.title('Genia No PTB')
plt.show()

# %% [markdown]
# # Genia Bidirectional PTB Accuracy

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
valid_bi_ptb = [
0.804364,
0.867376,
0.863578,
0.874488,
0.872360,
0.882274,
0.885830,
0.888551,
0.882920,
0.888173,
0.892026,
0.897980,
0.899192,
0.898087,
0.896498,
0.893642,
0.897225,
0.900970,
0.901589,
0.898949,
0.900808,
0.901239,
0.898895,
0.899973,
0.897629,
0.898788,
0.898572,
0.902398,
0.899327,
0.899650,
]
train_bi_ptb = [
0.526382,
0.841767,
0.870653,
0.879413,
0.886541,
0.890756,
0.894953,
0.897608,
0.900393,
0.903115,
0.904874,
0.907729,
0.907570,
0.910231,
0.910646,
0.911483,
0.911247,
0.912572,
0.913445,
0.914686,
0.915311,
0.915214,
0.915614,
0.915420,
0.916095,
0.916161,
0.916353,
0.916438,
0.917233,
0.917231,
]

# %%
trainminus_bi_ptb = [1-x for x in train_bi_ptb]
validminus_bi_ptb = [1-y for y in valid_bi_ptb]

plt.plot(trainminus_bi_ptb, label='train')
plt.plot(validminus_bi_ptb, label='validation')
plt.ylabel('Chunk Validation Error (Accuracy)')
plt.xlabel('Epoch')
plt.legend()
plt.title("Genia Bidirectional PTB")
plt.show()

# %% [markdown]
# # Comparing Different Models Genia

# %%
plt.plot(validminus_bi_ptb, label='validation_bi_ptb')
plt.plot(validminus_30_ptb, label="validation_ptb")
plt.plot(validminus_no_ptb, label='validation_no_ptb')
plt.ylabel('Chunk Validation Error (Accuracy)')
plt.xlabel('Epoch')
plt.legend()
plt.title("Comparing Validation Between Models")
plt.show()

# %% [markdown]
# # Conll Chunk LM PTB

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
train_30_ptb_conll = [
0.531079,
0.869146,
0.896191,
0.907818,
0.916564,
0.921833,
0.925927,
0.928874,
0.931875,
0.934495,
0.936605,
0.937358,
0.938703,
0.939897,
0.941158,
0.942058,
0.943083,
0.943405,
0.944218,
0.945146,
0.945598,
0.946668,
0.946894,
0.947582,
0.947989,
0.948355,
0.948788,
0.949680,
0.950011,
0.950919
]
valid_30_ptb_conll = [
0.837647,
0.890949,
0.909139,
0.915537,
0.918175,
0.922759,
0.924042,
0.924573,
0.925870,
0.926548,
0.927196,
0.927889,
0.929348,
0.929923,
0.929953,
0.931029,
0.930012,
0.930646,
0.930926,
0.930587,
0.930985,
0.931442,
0.932547,
0.931943,
0.931810,
0.931677,
0.931972,
0.932193,
0.932002,
0.932105
]

# %%
trainminus_30_ptb_conll = [1-x for x in train_30_ptb_conll]
validminus_30_ptb_conll = [1-y for y in valid_30_ptb_conll]

plt.plot(trainminus_30_ptb_conll, label='train')
plt.plot(validminus_30_ptb_conll, label='validation')
plt.ylabel('Chunk Validation Error (Accuracy)')
plt.xlabel('Epoch')
plt.legend()
plt.title('Conll LM PTB')
plt.show()

# %% [markdown]
# # Conll no ptb accuracy

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
valid_no_ptb_conll = [
0.767188,
0.858505,
0.878788,
0.891716,
0.900044,
0.904687,
0.908269,
0.910923,
0.912249,
0.912972,
0.914549,
0.916067,
0.917173,
0.916966,
0.918042,
0.917143,
0.918794,
0.918514,
0.919001,
0.919546,
0.920254,
0.920136,
0.920091,
0.920106,
0.920430,
0.919723,
0.918986,
0.918883,
0.919517,
0.918529
]
train_no_ptb_conll = [
0.447305,
0.823232,
0.863374,
0.881965,
0.892499,
0.899364,
0.906694,
0.911322,
0.916148,
0.919213,
0.923292,
0.924967,
0.928264,
0.929767,
0.931905,
0.933342,
0.935633,
0.936838,
0.938500,
0.939870,
0.942075,
0.942598,
0.944637,
0.945140,
0.946153,
0.946868,
0.948404,
0.949179,
0.950364,
0.950828
]

# %%
trainminus_no_ptb_conll = [1-x for x in train_no_ptb_conll]
validminus_no_ptb_conll = [1-y for y in valid_no_ptb_conll]

plt.plot(trainminus_no_ptb_conll, label='train')
plt.plot(validminus_no_ptb_conll, label='validation')
plt.ylabel('Chunk Validation Error (Accuracy)')
plt.xlabel('Epoch')
plt.legend()
plt.title('Conll No PTB')
plt.show()

# %% [markdown]
# # Conll Bidirectional PTB

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
valid_bi_ptb_conll = [
0.838193,
0.891598,
0.910186,
0.914446,
0.920180,
0.923098,
0.922833,
0.925074,
0.924882,
0.926666,
0.927314,
0.927565,
0.928272,
0.927845,
0.929098,
0.928626,
0.929378,
0.929437,
0.930808,
0.930955,
0.930100,
0.930896,
0.931648,
0.931309,
0.931279,
0.931191,
0.931309,
0.930852,
0.930808,
0.931899
]
train_bi_ptb_conll = [
0.506010,
0.867544,
0.897930,
0.910964,
0.917127,
0.923056,
0.926857,
0.929869,
0.932062,
0.934624,
0.936302,
0.938018,
0.939835,
0.941224,
0.942448,
0.943961,
0.944644,
0.945442,
0.946309,
0.946289,
0.948141,
0.948613,
0.948673,
0.949230,
0.950256,
0.950393,
0.950508,
0.950975,
0.951287,
0.951615
]

# %%
trainminus_bi_ptb_conll = [1-x for x in train_bi_ptb_conll]
validminus_bi_ptb_conll = [1-y for y in valid_bi_ptb_conll]

plt.plot(trainminus_bi_ptb_conll, label='train')
plt.plot(validminus_bi_ptb_conll, label='validation')
plt.ylabel('Chunk Validation Error (Accuracy)')
plt.xlabel('Epoch')
plt.legend()
plt.title("Conll Bidirectional PTB")
plt.show()

# %% [markdown]
# # Comparator - Conll

# %%
plt.plot(validminus_bi_ptb_conll, label='validation_bi_conll')
plt.plot(validminus_30_ptb_conll, label="validation_conll")
plt.plot(validminus_no_ptb_conll, label='validation_no_conll')
plt.ylabel('Chunk Validation Error (Accuracy)')
plt.xlabel('Epoch')
plt.legend()
plt.title("Comparing Validation Between Models - Conll")
