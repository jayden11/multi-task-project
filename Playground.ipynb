# %%
import pandas as pd
train_custom = pd.read_csv('/Users/jonathangodwin/project/data/current_outcome/chunk_pred_val.txt', sep= ' ',header=None)

# %%
a = pd.concat([train_custom,train_targ,train_pred],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4196e39c98e7> in <module>()
# ----> 1 a = pd.concat([train_custom,train_targ,train_pred],axis=1)
#
# NameError: name 'train_targ' is not defined

# %%
train = pd.read_csv('/Users/jonathangodwin/project/data/train_custom.txt', sep= ' ',header=None)

# %%
import numpy as np
len(np.unique(train[1].as_matrix()))
# Out:
# 44

# %%
train_custom
# Out:
#                 0     1       2       3
# 0               a    DT    B-NP       0
# 1           trade    NN    I-NP       0
# 2           group    NN    I-NP       0
# 3               ,     ,       O       O
# 4            will    MD    B-VP    B-VP
# 5            sell    VB    I-VP    I-VP
# 6          access    NN    B-NP    B-NP
# 7              to    TO    B-PP    B-PP
# 8             the    DT    B-NP    B-NP
# 9         package    NN    I-NP    I-NP
# 10             to    TO    B-PP    B-PP
# 11            its  PRP$    B-NP    B-NP
# 12            180    CD    I-NP    I-NP
# 13        airline    NN    I-NP    I-NP
# 14        members   NNS    I-NP    I-NP
# 15     world-wide    JJ  B-ADVP  B-ADJP
# 16              .     .       O       O
# 17        Control   NNP    B-NP    B-NP
# 18           Data   NNP    I-NP    I-NP
# 19           will    MD    B-VP    B-VP
# 20        receive    VB    I-VP    I-VP
# 21        revenue    NN    B-NP    B-NP
# ...

# %%
a
# Out:
#                     0    1       2       0       0
# 0          Confidence   NN    B-NP   B-UCP   B-UCP
# 1                  in   IN    B-PP   B-UCP   B-UCP
# 2                 the   DT    B-NP    I-NP    I-NP
# 3               pound   NN    I-NP       O       O
# 4                  is  VBZ    B-VP    B-PP    B-PP
# 5              widely   RB    I-VP    I-NP    I-NP
# 6            expected  VBN    I-VP   B-UCP   B-UCP
# 7                  to   TO    I-VP    B-VP    B-VP
# 8                take   VB    I-VP    I-NP    I-NP
# 9             another   DT    B-NP   B-UCP   B-UCP
# 10              sharp   JJ    I-NP       O       O
# 11               Dive   NN    I-NP    B-PP    B-PP
# 12                 if   IN  B-SBAR  I-ADJP  I-ADJP
# 13              trade   NN    B-NP    I-VP    I-VP
# 14            figures  NNS    I-NP    B-NP    B-NP
# 15                for   IN    B-PP    I-NP    I-NP
# 16          September  NNP    B-NP   B-UCP   B-UCP
# ...

# %%
def _int_to_POS(pos_int, POS_vocab_size):
    a = np.empty(POS_vocab_size)
    a.fill(0)
    pdb.set_trace()
    return np.put(a,pos_int-1,1)

# %%
_int_to_POS(4,5)

# %%
a = np.empty(10)

# %%
a.fill(1)

# %%
a
